# %% [markdown]
# ### How to separate countries and regions

# %%
import pandas as pd

# %%
df = pd.read_csv("https://github.com/berdikhanova/DS4SG-Global-Inequality/blob/Assignment/Data/Final/indicators.csv?raw=true")

# %% [markdown]
# ### Only countries

# %%
ISOs_Country = {
'ABW':'Aruba', 'AFG':'Afghanistan','AGO':'Angola','AIA':'Anguilla','ALA':'Åland Islands','ALB':'Albania',
'AND':'Andorra','ARE':'United Arab Emirates','ARG':'Argentina','ARM':'Armenia','ASM':'American Samoa',
'ATA':'Antarctica','ATF':'French Southern Territories','ATG':'Antigua and Barbuda','AUS':'Australia',
'AUT':'Austria','AZE':'Azerbaijan','BDI':'Burundi','BEL':'Belgium','BEN':'Benin',
'BES':'Bonaire, Sint Eustatius and Saba','BFA':'Burkina Faso','BGD':'Bangladesh','BGR':'Bulgaria',
'BHR':'Bahrain','BHS':'Bahamas','BIH':'Bosnia and Herzegovina','BLM':'Saint Barthélemy','BLR':'Belarus',
'BLZ':'Belize','BMU':'Bermuda','BOL':'Bolivia (Plurinational State of)','BRA':'Brazil','BRB':'Barbados',
'BRN':'Brunei Darussalam','BTN':'Bhutan','BVT':'Bouvet Island','BWA':'Botswana','CAF':'Central African Republic',
'CAN':'Canada','CCK':'Cocos (Keeling) Islands','CHE':'Switzerland','CHL':'Chile','CHN':'China',
'CIV':'Côte d\'Ivoire','CMR':'Cameroon','COD':'Democratic Republic of the Congo','COG':'Congo',
'COK':'Cook Islands','COL':'Colombia','COM':'Comoros','CPV':'Cabo Verde','CRI':'Costa Rica','CUB':'Cuba',
'CUW':'Curaçao','CXR':'Christmas Island','CYM':'Cayman Islands','CYP':'Cyprus','CZE':'Czechia',
'DEU':'Germany','DJI':'Djibouti','DMA':'Dominica','DNK':'Denmark','DOM':'Dominican Republic','DZA':'Algeria',
'ECU':'Ecuador','EGY':'Egypt','ERI':'Eritrea','ESH':'Western Sahara','ESP':'Spain','EST':'Estonia',
'ETH':'Ethiopia','FIN':'Finland','FJI':'Fiji','FLK':'Falkland Islands (Malvinas)','FRA':'France',
'FRO':'Faroe Islands','FSM':'Micronesia (Federated States of)','GAB':'Gabon',
'GBR':'United Kingdom of Great Britain and Northern Ireland','GEO':'Georgia','GGY':'Guernsey','GHA':'Ghana',
'GIB':'Gibraltar','GIN':'Guinea','GLP':'Guadeloupe','GMB':'Gambia','GNB':'Guinea-Bissau',
'GNQ':'Equatorial Guinea','GRC':'Greece','GRD':'Grenada','GRL':'Greenland','GTM':'Guatemala',
'GUF':'French Guiana','GUM':'Guam','GUY':'Guyana','HKG':'Hong Kong','HMD':'Heard Island and McDonald Islands',
'HND':'Honduras','HRV':'Croatia','HTI':'Haiti','HUN':'Hungary','IDN':'Indonesia','IMN':'Isle of Man',
'IND':'India','IOT':'British Indian Ocean Territory','IRL':'Ireland','IRN':'Iran (Islamic Republic of)',
'IRQ':'Iraq','ISL':'Iceland','ISR':'Israel','ITA':'Italy','JAM':'Jamaica','JEY':'Jersey','JOR':'Jordan',
'JPN':'Japan','KAZ':'Kazakhstan','KEN':'Kenya','KGZ':'Kyrgyzstan','KHM':'Cambodia','KIR':'Kiribati',
'KNA':'Saint Kitts and Nevis','KOR':'Republic of Korea','KWT':'Kuwait','LAO':'Lao People\'s Democratic Republic',
'LBN':'Lebanon','LBR':'Liberia','LBY':'Libya','LCA':'Saint Lucia', 'LIE':'Liechtenstein','LKA':'Sri Lanka',
'LSO':'Lesotho','LTU':'Lithuania','LUX':'Luxembourg','LVA':'Latvia','MAC':'Macao',
'MAF':'Saint Martin (French part)','MAR':'Morocco','MCO':'Monaco','MDA':'Republic of Moldova',
'MDG':'Madagascar','MDV':'Maldives','MEX':'Mexico','MHL':'Marshall Islands','MKD':'North Macedonia',
'MLI':'Mali','MLT':'Malta','MMR':'Myanmar','MNE':'Montenegro','MNG':'Mongolia','MNP':'Northern Mariana Islands',
'MOZ':'Mozambique','MRT':'Mauritania','MSR':'Montserrat','MTQ':'Martinique','MUS':'Mauritius','MWI':'Malawi',
'MYS':'Malaysia','MYT':'Mayotte','NAM':'Namibia','NCL':'New Caledonia','NER':'Niger','NFK':'Norfolk Island',
'NGA':'Nigeria','NIC':'Nicaragua','NIU':'Niue','NLD':'Netherlands','NOR':'Norway','NPL':'Nepal','NRU':'Nauru',
'NZL':'New Zealand','OMN':'Oman','PAK':'Pakistan','PAN':'Panama','PCN':'Pitcairn','PER':'Peru','PHL':'Philippines',
'PLW':'Palau','PNG':'Papua New Guinea','POL':'Poland','PRI':'Puerto Rico','PRK':'Democratic People\'s Republic of Korea',
'PRT':'Portugal','PRY':'Paraguay','PSE':'Palestine, State of','PYF':'French Polynesia','QAT':'Qatar','REU':'Réunion',
'ROU':'Romania','RUS':'Russian Federation','RWA':'Rwanda','SAU':'Saudi Arabia','SDN':'Sudan','SEN':'Senegal',
'SGP':'Singapore','SGS':'South Georgia and the South Sandwich Islands','SHN':'Saint Helena, Ascension and Tristan da Cunha',
'SJM':'Svalbard and Jan Mayen','SLB':'Solomon Islands','SLE':'Sierra Leone','SLV':'El Salvador','SMR':'San Marino',
'SOM':'Somalia','SPM':'Saint Pierre and Miquelon','SRB':'Serbia','SSD':'South Sudan','STP':'Sao Tome and Principe',
'SUR':'Suriname','SVK':'Slovakia','SVN':'Slovenia','SWE':'Sweden','SWZ':'Eswatini','SXM':'Sint Maarten (Dutch part)',
'SYC':'Seychelles','SYR':'Syrian Arab Republic','TCA':'Turks and Caicos Islands','TCD':'Chad','TGO':'Togo',
'THA':'Thailand','TJK':'Tajikistan','TKL':'Tokelau','TKM':'Turkmenistan','TLS':'Timor-Leste','TON':'Tonga',
'TTO':'Trinidad and Tobago','TUN':'Tunisia','TUR':'Turkey','TUV':'Tuvalu','TWN':'Taiwan, Province of China',
'TZA':'United Republic of Tanzania','UGA':'Uganda','UKR':'Ukraine','UMI':'United States Minor Outlying Islands',
'URY':'Uruguay','USA':'United States of America','UZB':'Uzbekistan','VAT':'Holy See','VCT':'Saint Vincent and the Grenadines',
'VEN':'Venezuela (Bolivarian Republic of)','VGB':'Virgin Islands (British)','VIR':'Virgin Islands (U.S.)','VNM':'Viet Nam',
'VUT':'Vanuatu','WLF':'Wallis and Futuna','WSM':'Samoa','YEM':'Yemen','ZAF':'South Africa','ZMB':'Zambia',
'ZWE':'Zimbabwe','XKX': 'Kosovo'}

ISO_alpha3 = ISOs_Country.keys()

# %%
df_noncountries = df[~df['Country Code'].isin(ISO_alpha3)]
df_onlycountries = df[df['Country Code'].isin(ISO_alpha3)]

# %%
df_onlycountries
df_noncountries
# Out:
#                                      Country Name Country Code  \
# 0                     Africa Eastern and Southern          AFE
# 1                     Africa Eastern and Southern          AFE
# 2                     Africa Eastern and Southern          AFE
# 3                     Africa Eastern and Southern          AFE
# 4                      Africa Western and Central          AFW
# ...                                           ...          ...
# 80996                          Sub-Saharan Africa          SSF
# 80997  Sub-Saharan Africa (excluding high income)          SSA
# 80998   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 80999                         Upper middle income          UMC
# 81000                                       World          WLD
#
#           Indicator Code                            Indicator Name  Date  \
# 0         NY.GDP.PCAP.CD              GDP per capita (current US$)  1960
# 1      SP.DYN.LE00.FE.IN  Life expectancy at birth, female (years)  1960
# 2      SP.DYN.LE00.MA.IN    Life expectancy at birth, male (years)  1960
# 3         SP.DYN.LE00.IN   Life expectancy at birth, total (years)  1960
# 4         NY.GDP.PCAP.CD              GDP per capita (current US$)  1960
# ...                  ...                                       ...   ...
# 80996     NY.GDP.PCAP.CD              GDP per capita (current US$)  2021
# 80997     NY.GDP.PCAP.CD              GDP per capita (current US$)  2021
# 80998     NY.GDP.PCAP.CD              GDP per capita (current US$)  2021
# 80999     NY.GDP.PCAP.CD              GDP per capita (current US$)  2021
# 81000     NY.GDP.PCAP.CD              GDP per capita (current US$)  2021
#
#               value
# 0        162.726325
# 1         44.300571
# 2         41.177958
# 3         42.716053
# 4        107.930722
# ...             ...
# 80996   1645.472944
# 80997   1644.480362
# 80998   1645.472944
# 80999  10835.523168
# 81000  12262.934615
#
# [15935 rows x 6 columns]

# %%
pathname = "/Users/norika_machome/GitHub/DS4SG-Global-Inequality"


def create_df_countrytype(df,write_to = None):
    df.to_csv(pathname + "/Data/Final/" + write_to + ".csv", index = False)
    print("Written to:", pathname + "/Data/Final/" + write_to + ".csv")
    return df

create_df_countrytype(df_onlycountries, write_to= "df_countries")
# Out:
# Written to: /Users/norika_machome/GitHub/DS4SG-Global-Inequality/Data/Final/df_countries.csv
#              Country Name Country Code     Indicator Code  \
# 183           Afghanistan          AFG     NY.GDP.PCAP.CD
# 184           Afghanistan          AFG  SP.DYN.LE00.FE.IN
# 185           Afghanistan          AFG  SP.DYN.LE00.MA.IN
# 186           Afghanistan          AFG     SP.DYN.LE00.IN
# 187               Albania          ALB  SP.DYN.LE00.FE.IN
# ...                   ...          ...                ...
# 81238  West Bank and Gaza          PSE     NY.GDP.PCAP.CD
# 81239  West Bank and Gaza          PSE     SL.UEM.NEET.ZS
# 81240         Yemen, Rep.          YEM     NY.GDP.PCAP.CD
# 81241              Zambia          ZMB     NY.GDP.PCAP.CD
# 81242            Zimbabwe          ZWE     NY.GDP.PCAP.CD
#
#                                           Indicator Name  Date        value
# 183                         GDP per capita (current US$)  1960    59.773234
# 184             Life expectancy at birth, female (years)  1960    33.314000
# 185               Life expectancy at birth, male (years)  1960    31.718000
# 186              Life expectancy at birth, total (years)  1960    32.446000
# 187             Life expectancy at birth, female (years)  1960    63.247000
# ...                                                  ...   ...          ...
# 81238                       GDP per capita (current US$)  2021  3663.969055
# 81239  Share of youth not in education, employment or...  2021    31.510000
# 81240                       GDP per capita (current US$)  2021   690.759273
# 81241                       GDP per capita (current US$)  2021  1120.630171
# 81242                       GDP per capita (current US$)  2021  1737.173977
#
# [65308 rows x 6 columns]

# %% [markdown]
# ### Only economic status

# %%
economic_code_dict = {
'UMC':'Upper middle income',
 'MIC':'Middle income',
 'LMY':'Low & middle income',
 'LIC':'Low income',
 'LMC':'Lower middle income',
 'HIC':'High income'}

economic_code = economic_code_dict.keys()
df_economic = df_noncountries[df_noncountries['Country Code'].isin(economic_code)]
df_economic.head(3)
# Out:
#    Country Name Country Code     Indicator Code  \
# 59  High income          HIC     EG.ELC.COAL.ZS
# 60  High income          HIC     NY.GDP.PCAP.CD
# 61  High income          HIC  SP.DYN.LE00.FE.IN
#
#                                        Indicator Name  Date        value
# 59  Electricity production from coal sources (% of...  1960    45.904345
# 60                       GDP per capita (current US$)  1960  1372.007466
# 61           Life expectancy at birth, female (years)  1960    71.397075

# %%
create_df_countrytype(df_economic, write_to= "df_economic")
# Out:
# Written to: /Users/norika_machome/GitHub/DS4SG-Global-Inequality/Data/Final/df_economic.csv
#               Country Name Country Code     Indicator Code  \
# 59             High income          HIC     EG.ELC.COAL.ZS
# 60             High income          HIC     NY.GDP.PCAP.CD
# 61             High income          HIC  SP.DYN.LE00.FE.IN
# 62             High income          HIC  SP.DYN.LE00.MA.IN
# 63             High income          HIC     SP.DYN.LE00.IN
# ...                    ...          ...                ...
# 80977  Low & middle income          LMY     NY.GDP.PCAP.CD
# 80978           Low income          LIC     NY.GDP.PCAP.CD
# 80979  Lower middle income          LMC     NY.GDP.PCAP.CD
# 80983        Middle income          MIC     NY.GDP.PCAP.CD
# 80999  Upper middle income          UMC     NY.GDP.PCAP.CD
#
#                                           Indicator Name  Date         value
# 59     Electricity production from coal sources (% of...  1960     45.904345
# 60                          GDP per capita (current US$)  1960   1372.007466
# 61              Life expectancy at birth, female (years)  1960     71.397075
# 62                Life expectancy at birth, male (years)  1960     65.684805
# 63               Life expectancy at birth, total (years)  1960     68.472644
# ...                                                  ...   ...           ...
# 80977                       GDP per capita (current US$)  2021   5530.438553
# 80978                       GDP per capita (current US$)  2021    749.761380
# 80979                       GDP per capita (current US$)  2021   2581.857195
# 80983                       GDP per capita (current US$)  2021   6102.000869
# 80999                       GDP per capita (current US$)  2021  10835.523168
#
# [1935 rows x 6 columns]

# %% [markdown]
# ### Only Regional State

# %%
regional_code_dict = {
    "AFE":	"Africa Eastern and Southern",
    "AFW":	"Africa Western and Central",
    "ARB":	"Arab World",
    "CEB":	"Central Europe and the Baltics",
    "CSS":	"Caribbean small states",
    "EAS":	"East Asia & Pacific",
    "ECS":	"Europe & Central Asia",
    "EUU":	"European Union",
    "LCN":	"Latin America & Caribbean",
    "MEA":	"Middle East & North Africa",
    "NAC":	"North America",
    "SAS":	"South Asia",
    "SSF":	"Sub-Saharan Africa"}

regional_code = regional_code_dict.keys()
df_region = df_noncountries[df_noncountries['Country Code'].isin(regional_code)]
df_region.head(3)
# Out:
#                                 Country Name  Indicator Code  \
# Country Code
# AFE              Africa Eastern and Southern  NY.GDP.PCAP.CD
# AFW               Africa Western and Central  NY.GDP.PCAP.CD
# ARB                               Arab World  NY.GDP.PCAP.CD
# CEB           Central Europe and the Baltics  SL.UEM.NEET.ZS
# CSS                   Caribbean small states  NY.GDP.PCAP.CD
# EAS                      East Asia & Pacific  NY.GDP.PCAP.CD
# ECS                    Europe & Central Asia  NY.GDP.PCAP.CD
# EUU                           European Union  SL.UEM.NEET.ZS
# LCN                Latin America & Caribbean  SL.UEM.NEET.ZS
# MEA               Middle East & North Africa  NY.GDP.PCAP.CD
# NAC                            North America  SL.UEM.NEET.ZS
# SAS                               South Asia  NY.GDP.PCAP.CD
# SSF                       Sub-Saharan Africa  NY.GDP.PCAP.CD
#
#                                                  Indicator Name  Date  \
# Country Code
# AFE                                GDP per capita (current US$)  2021
# AFW                                GDP per capita (current US$)  2021
# ARB                                GDP per capita (current US$)  2021
# CEB           Share of youth not in education, employment or...  2021
# CSS                                GDP per capita (current US$)  2021
# EAS                                GDP per capita (current US$)  2021
# ECS                                GDP per capita (current US$)  2021
# EUU           Share of youth not in education, employment or...  2021
# LCN           Share of youth not in education, employment or...  2021
# MEA                                GDP per capita (current US$)  2021
# NAC           Share of youth not in education, employment or...  2021
# SAS                                GDP per capita (current US$)  2021
# SSF                                GDP per capita (current US$)  2021
#
#                      value
# Country Code
# AFE            1557.722682
# AFW            1774.921218
# ARB            6412.389210
# CEB              12.068169
# CSS            9352.282028
# EAS           13037.462641
# ECS           27114.275990
# EUU              10.805050
# LCN              21.361792
# MEA            7696.868480
# NAC              12.270736
# SAS            2176.776671
# SSF            1645.472944

# %%
create_df_countrytype(df_economic, write_to= "df_region")
# Out:
# Written to: /Users/norika_machome/GitHub/DS4SG-Global-Inequality/Data/Final/df_region.csv
#               Country Name Country Code     Indicator Code  \
# 59             High income          HIC     EG.ELC.COAL.ZS
# 60             High income          HIC     NY.GDP.PCAP.CD
# 61             High income          HIC  SP.DYN.LE00.FE.IN
# 62             High income          HIC  SP.DYN.LE00.MA.IN
# 63             High income          HIC     SP.DYN.LE00.IN
# ...                    ...          ...                ...
# 80977  Low & middle income          LMY     NY.GDP.PCAP.CD
# 80978           Low income          LIC     NY.GDP.PCAP.CD
# 80979  Lower middle income          LMC     NY.GDP.PCAP.CD
# 80983        Middle income          MIC     NY.GDP.PCAP.CD
# 80999  Upper middle income          UMC     NY.GDP.PCAP.CD
#
#                                           Indicator Name  Date         value
# 59     Electricity production from coal sources (% of...  1960     45.904345
# 60                          GDP per capita (current US$)  1960   1372.007466
# 61              Life expectancy at birth, female (years)  1960     71.397075
# 62                Life expectancy at birth, male (years)  1960     65.684805
# 63               Life expectancy at birth, total (years)  1960     68.472644
# ...                                                  ...   ...           ...
# 80977                       GDP per capita (current US$)  2021   5530.438553
# 80978                       GDP per capita (current US$)  2021    749.761380
# 80979                       GDP per capita (current US$)  2021   2581.857195
# 80983                       GDP per capita (current US$)  2021   6102.000869
# 80999                       GDP per capita (current US$)  2021  10835.523168
#
# [1935 rows x 6 columns]

# %% [markdown]
# ### Rest of the dataset

# %%
rest_df = df_noncountries[(~df_noncountries['Country Code'].isin(regional_code))&(~df_noncountries['Country Code'].isin(economic_code))&(~df_noncountries['Country Code'].isin(ISO_alpha3))]
rest_df.groupby("Country Code").last()
# Out:
#                                                    Country Name  \
# Country Code
# CHI                                             Channel Islands
# EAP                 East Asia & Pacific (excluding high income)
# EAR                                  Early-demographic dividend
# ECA               Europe & Central Asia (excluding high income)
# EMU                                                   Euro area
# FCS                    Fragile and conflict affected situations
# HPC                      Heavily indebted poor countries (HIPC)
# IBD                                                   IBRD only
# IBT                                            IDA & IBRD total
# IDA                                                   IDA total
# IDB                                                   IDA blend
# IDX                                                    IDA only
# LAC           Latin America & Caribbean (excluding high income)
# LDC                Least developed countries: UN classification
# LTE                                   Late-demographic dividend
# MNA           Middle East & North Africa (excluding high inc...
# OED                                                OECD members
# OSS                                          Other small states
# PRE                                    Pre-demographic dividend
# PSS                                 Pacific island small states
# PST                                   Post-demographic dividend
# SSA                  Sub-Saharan Africa (excluding high income)
# SST                                                Small states
# TEA                  East Asia & Pacific (IDA & IBRD countries)
# TEC                Europe & Central Asia (IDA & IBRD countries)
# TLA           Latin America & the Caribbean (IDA & IBRD coun...
# TMN           Middle East & North Africa (IDA & IBRD countries)
# TSA                                     South Asia (IDA & IBRD)
# TSS                   Sub-Saharan Africa (IDA & IBRD countries)
# WLD                                                       World
#
#               Indicator Code  \
# Country Code
# CHI           SP.DYN.LE00.IN
# EAP           NY.GDP.PCAP.CD
# EAR           NY.GDP.PCAP.CD
# ECA           NY.GDP.PCAP.CD
# EMU           SL.UEM.NEET.ZS
# FCS           NY.GDP.PCAP.CD
# HPC           NY.GDP.PCAP.CD
# IBD           NY.GDP.PCAP.CD
# IBT           NY.GDP.PCAP.CD
# IDA           NY.GDP.PCAP.CD
# IDB           NY.GDP.PCAP.CD
# IDX           NY.GDP.PCAP.CD
# LAC           SL.UEM.NEET.ZS
# LDC           NY.GDP.PCAP.CD
# LTE           NY.GDP.PCAP.CD
# MNA           NY.GDP.PCAP.CD
# OED           SL.UEM.NEET.ZS
# OSS           NY.GDP.PCAP.CD
# PRE           NY.GDP.PCAP.CD
# PSS           NY.GDP.PCAP.CD
# PST           SL.UEM.NEET.ZS
# SSA           NY.GDP.PCAP.CD
# SST           NY.GDP.PCAP.CD
# TEA           NY.GDP.PCAP.CD
# TEC           NY.GDP.PCAP.CD
# TLA           SL.UEM.NEET.ZS
# TMN           NY.GDP.PCAP.CD
# TSA           NY.GDP.PCAP.CD
# TSS           NY.GDP.PCAP.CD
# WLD           NY.GDP.PCAP.CD
#
#                                                  Indicator Name  Date  \
# Country Code
# CHI                     Life expectancy at birth, total (years)  2020
# EAP                                GDP per capita (current US$)  2021
# EAR                                GDP per capita (current US$)  2021
# ECA                                GDP per capita (current US$)  2021
# EMU           Share of youth not in education, employment or...  2021
# FCS                                GDP per capita (current US$)  2021
# HPC                                GDP per capita (current US$)  2021
# IBD                                GDP per capita (current US$)  2021
# IBT                                GDP per capita (current US$)  2021
# IDA                                GDP per capita (current US$)  2021
# IDB                                GDP per capita (current US$)  2021
# IDX                                GDP per capita (current US$)  2021
# LAC           Share of youth not in education, employment or...  2021
# LDC                                GDP per capita (current US$)  2021
# LTE                                GDP per capita (current US$)  2021
# MNA                                GDP per capita (current US$)  2021
# OED           Share of youth not in education, employment or...  2021
# OSS                                GDP per capita (current US$)  2021
# PRE                                GDP per capita (current US$)  2021
# PSS                                GDP per capita (current US$)  2021
# PST           Share of youth not in education, employment or...  2021
# SSA                                GDP per capita (current US$)  2021
# SST                                GDP per capita (current US$)  2021
# TEA                                GDP per capita (current US$)  2021
# TEC                                GDP per capita (current US$)  2021
# TLA           Share of youth not in education, employment or...  2021
# TMN                                GDP per capita (current US$)  2021
# TSA                                GDP per capita (current US$)  2021
# TSS                                GDP per capita (current US$)  2021
# WLD                                GDP per capita (current US$)  2021
#
#                      value
# Country Code
# CHI              83.240000
# EAP            9776.493809
# EAR            3739.957790
# ECA            8708.063638
# EMU              10.681148
# FCS            1826.396401
# HPC            1057.919242
# IBD            7241.958363
# IBT            5720.323923
# IDA            1456.412704
# IDB            1857.422562
# IDX            1254.267846
# LAC              21.552048
# LDC            1176.977617
# LTE           11452.820413
# MNA            3612.245533
# OED              13.735488
# OSS           13776.755847
# PRE            1437.208502
# PSS            3798.752777
# PST              11.409559
# SSA            1644.480362
# SST           12394.925909
# TEA            9884.678914
# TEC            9782.541967
# TLA              21.361792
# TMN            3611.601011
# TSA            2176.776671
# TSS            1645.472944
# WLD           12262.934615
